# %%
# !pip install pandas

# %%
import pandas as pd

df = pd.read_csv("employee_data.csv")
print(df , type(df))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.DataFrame'>

# %%
# DataFrames Method :  for EDA 
  # 1. df.head()  2. df.tail()  3. df.sample()  4. df.info()  5. df.shape   6. df.describe()  7. df.columns  8. df.uniques()
df

print(df.head())     #print starting 5 rows ( by default 5..) 
print("------" * 5)
print(df.head(2))     #print starting 2 rows ( by default 5.. as per paramter 2 )

print("------" * 15)
print(df.tail())     #print last 5 rows (by defautl 5...)
print("------" * 5)
print(df.tail(3))     #print last 5 rows (as per parameter 3)
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# ------------------------------
#    ID   Name  Age Department  Salary
# 0   1  Alice   25         HR   55000
# 1   2    Bob   32         IT   72000
# ------------------------------------------------------------------------------------------
#    ID    Name  Age Department  Salary
# 5   6   Frank   29    Finance   50000
# 6   7   Grace   41         HR   82000
# 7   8  Hannah   26  Marketing   47000
# 8   9     Ian   35         IT   75000
# 9  10   Julia   30    Finance   60000
# ------------------------------
#    ID    Name  Age Department  Salary
# 7   8  Hannah   26  Marketing   47000
# 8   9     Ian   35         IT   75000
# 9  10   Julia   30    Finance   60000

# %%
df.sample()    #Any random value or row print

# as per parameter also generted random values / row 
df.sample(2)
# Out:
#    ID   Name  Age Department  Salary
# 6   7  Grace   41         HR   82000
# 9  10  Julia   30    Finance   60000

# %%
df.info()    # give the summary of our data
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     str
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     str
#  4   Salary      10 non-null     int64
# dtypes: int64(3), str(2)
# memory usage: 628.0 bytes

# %%
df.shape          # Return tuple value (immutable) of rows an columns ( like 3 rows 5 column)
# no paramter has passed ()
# Out:
# (10, 5)

# %%
df.describe()   # give the stastic data of numeric columns( like mean , max ...etc)
# Out:
#              ID        Age        Salary
# count  10.00000  10.000000     10.000000
# mean    5.50000  32.900000  64500.000000
# std     3.02765   6.674162  15182.226451
# min     1.00000  25.000000  47000.000000
# 25%     3.25000  28.250000  51250.000000
# 50%     5.50000  31.000000  62500.000000
# 75%     7.75000  37.250000  74250.000000
# max    10.00000  45.000000  91000.000000

# %%
df.columns   #print all column of an csv file
# Out:
# Index(['ID', 'Name', 'Age', 'Department', 'Salary'], dtype='str')

# %%
df.nunique()    #print unique data count ( no repeated values ....)
# Out:
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64
